# %%
# The following will be helpful in you practice exercise


string_list = ['A', 'B', 'C', 'D']
num_list = [22, 56, 10, 31]

paired_list = list(zip(string_list, num_list))
print(paired_list) # OUTPUT: [('A', 22), ('B', 56), ('C', 10), ('D', 31)]

num_string_list = [(num, str) for str, num in paired_list]
print(num_string_list) # OUTPUT: [(22, 'A'), (56, 'B'), (10, 'C'), (31, 'D')]

sorted_num_string_list = sorted(num_string_list, reverse = True)
print(sorted_num_string_list) # OUTPUT: [(56, 'B'), (31, 'D'), (22, 'A'), (10, 'C')]

string_num_list = [(str, num) for num, str in sorted_num_string_list]
print(string_num_list) # OUTPUT: [('B', 56), ('D', 31), ('A', 22), ('C', 10)]

top_two_list = string_num_list[:2]
for str, num in top_two_list:
    print(f'{str} - {num}') # OUTPUT: B - 56, D - 31

# %% [markdown]
# For the practice exercise, you will write a small program that will accept a list of student names and grades, and allow you to view them and perform basic operations on them.
#
# REQUIREMENTS:
# 1. Accept a list of 10 names from the user. Each name must be separated by a comma
# 2. Similarly, accept a list of 10 grades (0 - 5). Each grade must be separated by a comma
#     2.1. Grades must be stored as integers after accepting them as inputs. (HINT: Use typecasting)
# 3. Store in a variable both the names and the grades together. (HINT: Use zip())
# 4. Display to the user the different options that they can choose from to interact with the program
#     4.1. First option is to view the student with the highest grade.
#     4.2. Second option is to view top three students with the highest grade (HINT: Use sorted())
#     4.3. Third option is to view the students with the lowest grade
#     4.4. Fourth option is to get the total number of students that failed
#     4.5. Quit the program
# 5. Use only the methods you have learned so far, including list methods and list comprehension.

# %%
# Accept names and grades from the user  
names_input = input("Enter 10 student names separated by commas: ").strip().split(',')  
grades_input = input("Enter 10 grades (0-5) separated by commas: ").strip().split(',')  
  
# Ensure grades are integers  
grades = [int(grade) for grade in grades_input]  
  
# Zip names and grades together  
students = list(zip(names_input, grades))  
  
# Function to display options and interact with the user  
def main_menu():  
    while True:  
        print("\nOptions:")  
        print("1. View the student with the highest grade")  
        print("2. View top three students with the highest grades")  
        print("3. View the student with the lowest grade")  
        print("4. Get the total number of students that failed")  
        print("5. Quit the program")  
          
        choice = input("Enter your choice (1-5): ").strip()  
          
        if choice == '1':  
            highest_grade_student = max(students, key=lambda x: x[1])  
            print(f"The student with the highest grade is: {highest_grade_student[0]} with a grade of {highest_grade_student[1]}")  
        elif choice == '2':  
            top_three = sorted(students, key=lambda x: x[1], reverse=True)[:3]  
            print("Top three students with the highest grades:")  
            for student in top_three:  
                print(f"{student[0]} with a grade of {student[1]}")  
        elif choice == '3':  
            lowest_grade_student = min(students, key=lambda x: x[1])  
            print(f"The student with the lowest grade is: {lowest_grade_student[0]} with a grade of {lowest_grade_student[1]}")  
        elif choice == '4':  
            failed_students = [student[0] for student in students if student[1] < 3]  # Assuming failing grade is <3  
            print(f"Total number of students that failed: {len(failed_students)}")  
            if failed_students:  
                print(f"Failed students: {', '.join(failed_students)}")  
        elif choice == '5':  
            print("Exiting the program.")  
            break  
        else:  
            print("Invalid choice. Please try again.")  
  
# Run the main menu  
main_menu()
# Out:
# Options:
# 1. View the student with the highest grade
# 2. View top three students with the highest grades
# 3. View the student with the lowest grade
# 4. Get the total number of students that failed
# 5. Quit the program
# The student with the highest grade is: ssd with a grade of 5
#
# Options:
# 1. View the student with the highest grade
# 2. View top three students with the highest grades
# 3. View the student with the lowest grade
# 4. Get the total number of students that failed
# 5. Quit the program
# Top three students with the highest grades:
# ssd with a grade of 5
# ssg with a grade of 5
# fg with a grade of 5
#
# Options:
# 1. View the student with the highest grade
# 2. View top three students with the highest grades
# 3. View the student with the lowest grade
# 4. Get the total number of students that failed
# 5. Quit the program
# Top three students with the highest grades:
# ssd with a grade of 5
# ssg with a grade of 5
# fg with a grade of 5
#
# Options:
# 1. View the student with the highest grade
# 2. View top three students with the highest grades
# 3. View the student with the lowest grade
# 4. Get the total number of students that failed
# 5. Quit the program
# Total number of students that failed: 4
# Failed students: zdw, gzy, ii, fg
#
# Options:
# 1. View the student with the highest grade
# 2. View top three students with the highest grades
# 3. View the student with the lowest grade
# 4. Get the total number of students that failed
# 5. Quit the program
# Exiting the program.
